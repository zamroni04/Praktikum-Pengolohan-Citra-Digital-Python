# %% [markdown]
# # Daftar Kegiatan Praktikum 3.1 - RGB
# 1. Percobaan 1 - Load From skimage.data
# 2. Percobaan 2 - Mengakses Channel RGB (versi 1)
# 3. Percobaan 3 - Mengakses Channel RGB (versi 2)

# %% [markdown]
# # Import Library

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from skimage import data
from skimage.io import imread
from skimage.color import rgb2gray

# %% [markdown]
# # Percobaan 1 - Load From skimage.data
# Sumber skimage data = https://scikit-image.org/docs/dev/api/skimage.data.html

# %%
original = data.astronaut()
print(original.shape)

plt.imshow(original)
# Out:
# (512, 512, 3)

# %% [markdown]
# # Percobaan 2 - Mengakses Channel RGB (versi 1)

# %%
red = original[:, :, 0]
green = original[:, :, 1]
blue = original[:, :, 2]

print('Red Shape = ',red.shape)
print('Green Shape = ',green.shape)
print('Blue Shape = ',blue.shape)

fig, axes = plt.subplots(2, 2, figsize=(10, 10))
ax = axes.ravel()

ax[0].imshow(original)
ax[0].set_title("Citra Input")

ax[1].imshow(red, cmap=plt.cm.gray)
ax[1].set_title("Red Channel")

ax[2].imshow(green, cmap=plt.cm.gray)
ax[2].set_title("Green Channel")

ax[3].imshow(blue, cmap=plt.cm.gray)
ax[3].set_title("Blue Channel")

fig.tight_layout()
plt.show()
# Out:
# Red Shape =  (512, 512)
# Green Shape =  (512, 512)
# Blue Shape =  (512, 512)

# %% [markdown]
# # Percobaan 3 - Mengakses Channel RGB (versi 2)

# %%
#red = original[:,:,0]
#green = original[:,:,1]
#blue = original[:,:,2]

red = original.copy() #red channel [0]
red[:,:,1]=0
red[:,:,2]=0
print('Red Shape = ',red.shape)

green = original.copy() #green channel [1]
green[:,:,0]=0
green[:,:,2]=0
print('Green Shape = ',green.shape)

blue = original.copy() #blue channel [2]
blue[:,:,0]=0
blue[:,:,1]=0
print('Blue Shape = ',blue.shape)

fig, axes = plt.subplots(2, 2, figsize=(10, 10))
ax = axes.ravel()
ax[0].imshow(original)
ax[0].set_title("Original")
ax[1].imshow(red)
ax[1].set_title("Red Channel")
ax[2].imshow(green)
ax[2].set_title("Green Channel")
ax[3].imshow(blue)
ax[3].set_title("Blue Channel")
fig.tight_layout()
plt.show()
# Out:
# Red Shape =  (512, 512, 3)
# Green Shape =  (512, 512, 3)
# Blue Shape =  (512, 512, 3)
